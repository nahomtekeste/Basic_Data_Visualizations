# %%
print("Hello worl this is the firs project ")
# Out:
# Hello worl this is the firs project

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [2, 6, 4]
y = [4 ,6, 6]
plt.plot(x,y)
plt.show()
